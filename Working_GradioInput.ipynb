# %% [markdown]
# <a href="https://colab.research.google.com/github/Stp155906/Data-Science-For-Beginners/blob/main/Working_GradioInput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using Gradio to create a simple interface.
#
# Check out the library on [github](https://github.com/gradio-app/gradio-UI) and see the [getting started](https://gradio.app/getting_started.html) page for more demos.

# %% [markdown]
# We'll start with a basic function that greets an input name.

# %%
def greet(name):
  return "Hello " + name + "!"

greet("World")

# %% [markdown]
# Now we'll wrap this function with a Gradio interface.

# %%
# !pip install -q gradio
# Out:
#      |████████████████████████████████| 5.1 MB 13.0 MB/s
#      |████████████████████████████████| 84 kB 3.4 MB/s
#      |████████████████████████████████| 1.1 MB 44.7 MB/s
#      |████████████████████████████████| 272 kB 49.4 MB/s
#      |████████████████████████████████| 54 kB 2.8 MB/s
#      |████████████████████████████████| 140 kB 56.7 MB/s
#      |████████████████████████████████| 212 kB 47.2 MB/s
#      |████████████████████████████████| 2.3 MB 46.9 MB/s
#      |████████████████████████████████| 57 kB 5.2 MB/s
#      |████████████████████████████████| 84 kB 3.7 MB/s
#      |████████████████████████████████| 271 kB 51.0 MB/s
#      |████████████████████████████████| 94 kB 3.5 MB/s
#      |████████████████████████████████| 144 kB 41.7 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
#      |████████████████████████████████| 80 kB 7.2 MB/s
#      |████████████████████████████████| 68 kB 3.3 MB/s
#      |████████████████████████████████| 54 kB 3.4 MB/s
# ...

# %%
import gradio

gradio.Interface(greet, "text", "text").launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://10487.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://10487.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fdf555fc690>,
#  'http://127.0.0.1:7860/',
#  'https://10487.gradio.app')

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# #Downloading data from a sheet into Python as a Pandas DataFrame
#
#
# ---
#
#
# Read back the random data that we inserted above and convert the result into a Pandas DataFrame.
# [6]
# 124567839
# worksheet = gc.open('Conscientious Choice').sheet1# get_all_values gives a list of rows.rows = worksheet.get_all_values()print(rows)import pandas as pdpd.DataFrame.from_records(rows)
#
# ---

# %%
worksheet = gc.open('Conscientious Choice').sheet1

#get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

import pandas as pd
list_all = pd.DataFrame.from_records(rows)
list_all
# Out:
# [['Category', 'Parent Company', 'Company', 'Score', '% Dem', 'Anti-Abortion candidate?', 'Metric Abortion', 'Pro-gun candidate?', 'Metric Gun', 'Pro-oil candidate?', 'Metric Oil', 'Anti-LGBTQ candidate?', 'Metric LGBTQ', 'Utilizes prison labor?', 'Environmental  Sourcing', 'Labor Sourcing', 'Historical  Allegations', '% of Discriminatory Cases per year'], ['Airline', '', 'Frontier', '81', '81', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['Airline', '', 'Alaska Airlines', '44', '54', '', '', 'Yes', '10', '', '', '', '', '', '', '', '', ''], ['Airline', '', 'United Airlines', '42', '72', 'Yes', '10', 'Yes', '10', 'Yes', '10', '', '', '', '', '', '', ''], ['Airline', '', 'Allegiant', '38', '38', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['Airline', '', 'Southwest', '36', '36', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['Airline', '', 'Delta', '34', '54', 'Yes', '10', 'Yes', '10', '', '', '', '', '', '', '', '', ''], ['Airline', '', 'JetBlue', '53', '53', 
# ...

# %%
# Renaming Columns
list_all.columns = [
                    'Category', 
                    'Parent Company', 
                    'Company', 
                    'Score', 
                    '% Dem', 
                    'Anti-Abortion candidate?', 
                    'Metric Abortion' ,
                    'Pro-gun candidate?',
                    'Metric Gun', 
                    'Pro-oil candidate?',
                    'Metric Oil', 
                    'Anti-LGBTQ candidate?',
                    'Metric LGBTQ',
                    'Utilizes prison labor?',
                    'Environmental Sourcing ', 
                    'Labor Sourcing', 
                    'Historical Allegations ',
                    '% of Discriminatory Cases per year']
list_all
#list_all = list_all.columns['Category', 'Parent Company', 'Company', '% Dem', 'Anti-Abortion candidate?',  'Pro-gun candidate?',  'Pro-oil candidate?',  'Anti-LGBTQ candidate?',  'Utilizes prison labor?', 'Labor Sourcing ', 'Environmental Sourcing ',  'Historical Allegations ', '% Discriminatory Cases PY']
# the list underneith each category
list_all
# Dropping. duplicate. labels row
data = list_all.drop(labels=0, axis=0)
data

# %% [markdown]
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Installing Dash
#
#
# ---

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Tesing Pycarat

# %%
# install slim version (default)
# !pip install pycaret

# %%
# Saving Dataframe to CSV 

data.to_csv('data.csv')

# %%
# load the iris dataset from pycaret repo
from pycaret.datasets import get_data
data = get_data('data')
# Out:
#    Unnamed: 0 Category Parent Company          Company  Score  % Dem  \
# 0           1  Airline            NaN         Frontier     81   81.0
# 1           2  Airline            NaN  Alaska Airlines     44   54.0
# 2           3  Airline            NaN  United Airlines     42   72.0
# 3           4  Airline            NaN        Allegiant     38   38.0
# 4           5  Airline            NaN        Southwest     36   36.0
#
#   Anti-Abortion candidate?  Metric Abortion Pro-gun candidate?  Metric Gun  \
# 0                      NaN              NaN                NaN         NaN
# 1                      NaN              NaN                Yes        10.0
# 2                      Yes             10.0                Yes        10.0
# 3                      NaN              NaN                NaN         NaN
# 4                      NaN              NaN                NaN         NaN
#
#   Pro-oil candidate?  Metric Oil Anti-LGBTQ candidate?  Metric LGBTQ  \
# ...

# %% [markdown]
# # Initialize Setup

# %%
# initialize setup
#from pycaret.classification import *
#s = setup(data, target = 'Category', session_id = 123)

# %% [markdown]
# # 👉 Compare Models
#
#
# ---
#
#
# This is the first step we recommend in the workflow of any supervised experiment in PyCaret. This function trains all the available models in the model library using default hyperparameters and evaluates performance metrics using cross-validation.
#
#
#
#
# ---
#
# The output of this function is a table showing the mean cross-validated scores for all the models. The number of folds can be defined using the foldparameter (default = 10 folds). The table is sorted (highest to lowest) by the metric of choice which can be defined using the sortparameter (default = ‘Accuracy’)

# %%
#best = compare_models(n_select = 15)
#compare_model_results = pull()

# %% [markdown]
# # 👽 Here is where I worked with the data
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
# ONLY need to uncomment this with new datasets
clean_data = data.drop(columns=data.columns[0])
clean_data
# Out:
#     Category Parent Company          Company  Score  % Dem  \
# 0    Airline            NaN         Frontier     81   81.0
# 1    Airline            NaN  Alaska Airlines     44   54.0
# 2    Airline            NaN  United Airlines     42   72.0
# 3    Airline            NaN        Allegiant     38   38.0
# 4    Airline            NaN        Southwest     36   36.0
# ..       ...            ...              ...    ...    ...
# 590      NaN            NaN              NaN      0    NaN
# 591      NaN            NaN              NaN      0    NaN
# 592      NaN            NaN              NaN      0    NaN
# 593      NaN            NaN              NaN      0    NaN
# 594      NaN            NaN              NaN      0    NaN
#
#     Anti-Abortion candidate?  Metric Abortion Pro-gun candidate?  Metric Gun  \
# 0                        NaN              NaN                NaN         NaN
# 1                        NaN              NaN                Yes        10.0
# ...

# %%
data
# The lower the number the least supportive vs higher the number being most supportive
# Out:
#      Unnamed: 0 Category Parent Company          Company  Score  % Dem  \
# 0             1  Airline            NaN         Frontier     81   81.0
# 1             2  Airline            NaN  Alaska Airlines     44   54.0
# 2             3  Airline            NaN  United Airlines     42   72.0
# 3             4  Airline            NaN        Allegiant     38   38.0
# 4             5  Airline            NaN        Southwest     36   36.0
# ..          ...      ...            ...              ...    ...    ...
# 590         591      NaN            NaN              NaN      0    NaN
# 591         592      NaN            NaN              NaN      0    NaN
# 592         593      NaN            NaN              NaN      0    NaN
# 593         594      NaN            NaN              NaN      0    NaN
# 594         595      NaN            NaN              NaN      0    NaN
#
#     Anti-Abortion candidate?  Metric Abortion Pro-gun candidate?  Metric Gun  \
# ...

# %% [markdown]
# ---
#
#
#
# # Part I — Creating an internal function Displaying UI

# %%
data_clean = pd.DataFrame(clean_data)
data_clean

clean_data = data_clean.to_csv('clean_data.csv')

# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
current_dir = os.path.dirname(os.path.realpath( '/content/clean_data.csv'))
data = pd.read_csv(os.path.join(current_dir, "/content/clean_data.csv"))

# %%
data.drop(columns=data.columns[0])
# Out:
#     Category Parent Company          Company  Score  % Dem  \
# 0    Airline            NaN         Frontier     81   81.0
# 1    Airline            NaN  Alaska Airlines     44   54.0
# 2    Airline            NaN  United Airlines     42   72.0
# 3    Airline            NaN        Allegiant     38   38.0
# 4    Airline            NaN        Southwest     36   36.0
# ..       ...            ...              ...    ...    ...
# 590      NaN            NaN              NaN      0    NaN
# 591      NaN            NaN              NaN      0    NaN
# 592      NaN            NaN              NaN      0    NaN
# 593      NaN            NaN              NaN      0    NaN
# 594      NaN            NaN              NaN      0    NaN
#
#     Anti-Abortion candidate?  Metric Abortion Pro-gun candidate?  Metric Gun  \
# 0                        NaN              NaN                NaN         NaN
# 1                        NaN              NaN                Yes        10.0
# ...

# %%
df_copy = data.copy()
df_copy['Category'] = df_copy['Score'].rank()
df_copy
# Out:
#      Unnamed: 0  Category Parent Company          Company  Score  % Dem  \
# 0             0     495.0            NaN         Frontier     81   81.0
# 1             1     216.0            NaN  Alaska Airlines     44   54.0
# 2             2     211.0            NaN  United Airlines     42   72.0
# 3             3     201.0            NaN        Allegiant     38   38.0
# 4             4     180.5            NaN        Southwest     36   36.0
# ..          ...       ...            ...              ...    ...    ...
# 590         590      22.0            NaN              NaN      0    NaN
# 591         591      22.0            NaN              NaN      0    NaN
# 592         592      22.0            NaN              NaN      0    NaN
# 593         593      22.0            NaN              NaN      0    NaN
# 594         594      22.0            NaN              NaN      0    NaN
#
#     Anti-Abortion candidate?  Metric Abortion Pro-gun candidate?  Metric Gun  \
# ...

# %%
import os

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import gradio as gr

current_dir = os.path.dirname(os.path.realpath('/content/titanic.csv'))
data = pd.read_csv(os.path.join(current_dir, "/content/titanic.csv"))


def encode_age(df):
    df.Age = df.Age.fillna(-0.5)
    bins = (-1, 0, 5, 12, 18, 25, 35, 60, 120)
    categories = pd.cut(df.Age, bins, labels=False)
    df.Age = categories
    return df


def encode_fare(df):
    df.Fare = df.Fare.fillna(-0.5)
    bins = (-1, 0, 8, 15, 31, 1000)
    categories = pd.cut(df.Fare, bins, labels=False)
    df.Fare = categories
    return df


def encode_df(df):
    df = encode_age(df)
    df = encode_fare(df)
    sex_mapping = {"male": 0, "female": 1}
    df = df.replace({"Sex": sex_mapping})
    embark_mapping = {"S": 1, "C": 2, "Q": 3}
    df = df.replace({"Embarked": embark_mapping})
    df.Embarked = df.Embarked.fillna(0)
    df["Company"] = 0
    df.loc[(df["SibSp"] > 0), "Company"] = 1
    df.loc[(df["Parch"] > 0), "Company"] = 2
    df.loc[(df["SibSp"] > 0) & (df["Parch"] > 0), "Company"] = 3
    df = df[
        [
            "PassengerId",
            "Pclass",
            "Sex",
            "Age",
            "Fare",
            "Embarked",
            "Company",
            "Survived",
        ]
    ]
    return df


train = encode_df(data)

X_all = train.drop(["Survived", "PassengerId"], axis=1)
y_all = train["Survived"]

num_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(
    X_all, y_all, test_size=num_test, random_state=23
)

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)


def predict_survival(passenger_class, is_male, age, company, fare, embark_point):
    if passenger_class is None or embark_point is None:
        return None
    df = pd.DataFrame.from_dict(
        {
            "Pclass": [passenger_class + 1],
            "Sex": [0 if is_male else 1],
            "Age": [age],
            "Company": [
                (1 if "Sibling" in company else 0) + (2 if "Child" in company else 0)
            ],
            "Fare": [fare],
            "Embarked": [embark_point + 1],
        }
    )
    df = encode_age(df)
    df = encode_fare(df)
    pred = clf.predict_proba(df)[0]
    return {"Perishes": float(pred[0]), "Survives": float(pred[1])}


demo = gr.Interface(
    predict_survival,
    [
        gr.Dropdown(["first", "second", "third"], type="index"),
        "checkbox",
        gr.Slider(0, 80),
        gr.CheckboxGroup(["Sibling", "Child"], label="Travelling with (select all)"),
        gr.Number(),
        gr.Radio(["S", "C", "Q"], type="index"),
    ],
    "label",
    examples=[
        ["first", True, 30, [], 50, "S"],
        ["second", False, 40, ["Sibling", "Child"], 10, "Q"],
        ["third", True, 30, ["Child"], 20, "S"],
    ],
    interpretation="default",
    live=True,
)

demo.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://47993.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://47993.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fdf3981cc10>,
#  'http://127.0.0.1:7861/',
#  'https://47993.gradio.app')

# %% [markdown]
# That's all! Go ahead and open that share link in a new tab. Check out our [getting started](https://gradio.app/getting_started.html) page for more complicated demos.

# %%
# Working Dataset

import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
#import gradio as gr


#current_dir = os.path.dirname(os.path.realpath( '/content/clean_data.csv'))
#data = pd.read_csv(os.path.join(current_dir, "/content/clean_data.csv"))





def encode_df(df):

    #df = encode_match(df)
    #df = encode_fare(df)

    # Pro Gun
    pro_mapping = {"no": 0, "yes": 1}
    df = df.replace({"Metric Gun": pro_mapping})

    # Pro oil
    pro_mapping = {"no": 0, "yes": 1}
    df = df.replace({"Metric Oil": pro_mapping})

    
    
    # Anti Abortion.   Prolife = meaning they are against abortion.. they recieve 0 (false) match rate, prochoice recieve true matchrate
    anti_mapping ={"yes": 0, "no": 1 }
    df = df.replace({"Metric Abortion": anti_mapping})

    # Anti LGBTQ.  anti meaning 0  for meaning true = 1
    anti_mapping ={"no": 0, "yes": 1 }
    df = df.replace({"Metric LGBTQ": anti_mapping})



    
    #embark_mapping = {"S": 1, "C": 2, "Q": 3}
    #df = df.replace({"Embarked": embark_mapping})
    #df.Embarked = df.Embarked.fillna(0)
    
    df = df[
        [
            "Category",
            "Parent Company",
            "Company",
            "Score",
            "% Dem",
            "Anti-Abortion candidate?", 
            "Metric Abortion" ,
            "Pro-gun candidate?",
            "Metric Gun", 
            "Pro-oil candidate?",
            "Metric Oil", 
            "Anti-LGBTQ candidate?",
            "Metric LGBTQ",
        ]

#category, parent_company, company, donated_Dem,is_NotProchoice, is_Not_Prochoice_metric_, wants_children_to_die, wants_children_to_die_metric, hates_earth,  hates_environment_metric, is_prolly_pedo_for_not_supportingLGBTQ, is_notcool_metric)

    ]
    return df






#clf = RandomForestClassifier()
#clf.fit(X_train, y_train)
#predictions = clf.predict(X_test)



# LABELS:   "Category","Parent Company", "Company", "% Dem","Anti-Abortion candidate?","Pro-gun candidate?", "Pro-oil candidate?","Anti-LGBTQ candidate?",
#. passenger_class, is_male, age, company, fare, embark_point


def predict_survival(category, parent_company, company, score, donated_Dem,is_NotProchoice, is_Not_Prochoice_metric_, wants_children_to_die, wants_children_to_die_metric, hates_earth,  hates_environment_metric, is_prolly_pedo_for_not_supportingLGBTQ, is_notcool_metric):
    if category is None or is_not_coolmetric is None:
        return None
    df = pd.DataFrame.from_dict(
        {   
            
            "Category": [category + 1],
            "Parent Company": [parent_company],
            "Company": [company],
            "Score": [score],
            "% Dem": [donated_Dem],
            "Metric Abortion": [0 if is_Not_Prochoice_metric_ else 1],
            "Metric Gun?": [0 if wants_children_to_die_metric else 1],
            "Metric Oil": [0 if hates_environment_metric else 1],
            "Metric LGBTQ": [0 if is_notcool_metric else 1],
         


            
            #"Embarked": [embark_point + 1],
        }
    )
    #df = encode_age(df)
    #df = encode_fare(df)

    #pred[df] = 1 — wants_children_to_die_metric[‘score’] * 0.1
    pred = clf.predict_proba(df)[0]
    return {"Score": float(pred[0]), "% Dem": float(pred[1])}


demo = gr.Interface(
    predict_survival,
    [
        gr.Dropdown(["Airline", "Auto Insurance", "Auto Part", "Baby", "Bank", "Candy", "Car Rental", "Cellular", "Cleaning Supplies", "Clothing", "Cosmetics", "Drinks", "Electronics", "Food", "Fragrances", "Grocery", "Hair Care", " Home Improvement", "Homeowner's Insurance", "Laundry", "Paper. Products", "Personal Care", " PetCare", "Pharmacy", "Restaurant", "Retail", "Shoes", "Skincare",  "Sportwear","Travel", "Entertainment Industry"], type="index"),
    
        gr.CheckboxGroup(["Pro-gun candidate?", "Pro-oil candidate?","Anti-LGBTQ candidate?","Anti-Abortion candidate?" ], label="Do They Support? "),
        
        gr.Radio(["Demo", "Repub", "Neutral"], type="index"),
    ],
    "label",
    
    interpretation="default",
    live=True,
)

demo.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://33462.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://33462.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fdf34e680d0>,
#  'http://127.0.0.1:7863/',
#  'https://33462.gradio.app')

# %%
generator1 = gr.Interface.load("huggingface/gpt2")
generator2 = gr.Interface.load("huggingface/EleutherAI/gpt-neo-2.7B")
generator3 = gr.Interface.load("huggingface/EleutherAI/gpt-j-6B")

gr.Parallel(generator1, generator2, generator3).launch()
# Out:
# Fetching model from: https://huggingface.co/gpt2
# Fetching model from: https://huggingface.co/EleutherAI/gpt-neo-2.7B
# Fetching model from: https://huggingface.co/EleutherAI/gpt-j-6B
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://41585.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://41585.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fdf32d9dd90>,
#  'http://127.0.0.1:7864/',
#  'https://41585.gradio.app')

# %% [markdown]
# # Image Input
#
#
# ---

# %%
import requests
import tensorflow as tf

import gradio as gr

inception_net = tf.keras.applications.MobileNetV2()  # load the model

# Download human-readable labels for ImageNet.
response = requests.get("https://git.io/JJkYN")
labels = response.text.split("\n")

def classify_image(inp):
    inp = inp.reshape((-1, 224, 224, 3))
    inp = tf.keras.applications.mobilenet_v2.preprocess_input(inp)
    prediction = inception_net.predict(inp).flatten()
    return {labels[i]: float(prediction[i]) for i in range(1000)}

image = gr.Image(shape=(224, 224))
label = gr.Label(num_top_classes=3)

demo = gr.Interface(
    fn=classify_image, inputs=image, outputs=label, interpretation="default"
)

demo.launch()
# Out:
# ...
# 14548992/14536120 [==============================] - 0s 0us/step
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://29907.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://29907.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fdec402da10>,
#  'http://127.0.0.1:7865/',
#  'https://29907.gradio.app')

# %%
# !pip install -q tensorflow-recommenders
# !pip install -q --upgrade tensorflow-datasets

# %% [markdown]
# https://colab.research.google.com/github/tensorflow/recommenders/blob/main/docs/examples/quickstart.ipynb#scrollTo=qA00wBE2Ntdm

# %% [markdown]
# ### Import TFRS
#
# First, install and import TFRS:

# %%
# !pip install -q tensorflow-recommenders
# !pip install -q --upgrade tensorflow-datasets
# Out:
#      |████████████████████████████████| 85 kB 3.7 MB/s
#      |████████████████████████████████| 4.3 MB 8.3 MB/s
#      |████████████████████████████████| 98 kB 9.8 MB/s

# %%
from typing import Dict, Text

import numpy as np
import tensorflow as tf

import tensorflow_datasets as tfds
import tensorflow_recommenders as tfrs

# %% [markdown]
# ### Read the data

# %%
# Ratings data.
ratings = tfds.load('movielens/100k-ratings', split="train")
# Features of all the available movies.
movies = tfds.load('movielens/100k-movies', split="train")

# Select the basic features.
ratings = ratings.map(lambda x: {
    "movie_title": x["movie_title"],
    "user_id": x["user_id"]
})
movies = movies.map(lambda x: x["movie_title"])
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/movielens/100k-ratings/0.1.1.incomplete9BXR67/movielens-train.tfrecord*...:   …
# Dataset movielens downloaded and prepared to ~/tensorflow_datasets/movielens/100k-ratings/0.1.1. Subsequent calls will reuse this data.
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/1682 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/movielens/100k-movies/0.1.1.incompleteE6UFJH/movielens-train.tfrecord*...:   0…
# Dataset movielens downloaded and prepared to ~/tensorflow_datasets/movielens/100k-movies/0.1.1. Subsequent calls will reuse this data.

# %% [markdown]
# Build vocabularies to convert user ids and movie titles into integer indices for embedding layers:

# %%
user_ids_vocabulary = tf.keras.layers.StringLookup(mask_token=None)
user_ids_vocabulary.adapt(ratings.map(lambda x: x["user_id"]))

movie_titles_vocabulary = tf.keras.layers.StringLookup(mask_token=None)
movie_titles_vocabulary.adapt(movies)

# %% [markdown]
# ### Define a model
#
# We can define a TFRS model by inheriting from `tfrs.Model` and implementing the `compute_loss` method:

# %%
class MovieLensModel(tfrs.Model):
  # We derive from a custom base class to help reduce boilerplate. Under the hood,
  # these are still plain Keras Models.

  def __init__(
      self,
      user_model: tf.keras.Model,
      movie_model: tf.keras.Model,
      task: tfrs.tasks.Retrieval):
    super().__init__()

    # Set up user and movie representations.
    self.user_model = user_model
    self.movie_model = movie_model

    # Set up a retrieval task.
    self.task = task

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    # Define how the loss is computed.

    user_embeddings = self.user_model(features["user_id"])
    movie_embeddings = self.movie_model(features["movie_title"])

    return self.task(user_embeddings, movie_embeddings)

# %% [markdown]
# Define the two models and the retrieval task.

# %%
# Define user and movie models.
user_model = tf.keras.Sequential([
    user_ids_vocabulary,
    tf.keras.layers.Embedding(user_ids_vocabulary.vocab_size(), 64)
])
movie_model = tf.keras.Sequential([
    movie_titles_vocabulary,
    tf.keras.layers.Embedding(movie_titles_vocabulary.vocab_size(), 64)
])

# Define your objectives.
task = tfrs.tasks.Retrieval(metrics=tfrs.metrics.FactorizedTopK(
    movies.batch(128).map(movie_model)
  )
)
# Out:
# WARNING:tensorflow:vocab_size is deprecated, please use vocabulary_size.
# WARNING:tensorflow:vocab_size is deprecated, please use vocabulary_size.
# WARNING:tensorflow:vocab_size is deprecated, please use vocabulary_size.
# WARNING:tensorflow:vocab_size is deprecated, please use vocabulary_size.

# %% [markdown]
# ### Fit and evaluate it.
#
# Create the model, train it, and generate predictions:

# %%
# Create a retrieval model.
model = MovieLensModel(user_model, movie_model, task)
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.5))

# Train for 3 epochs.
model.fit(ratings.batch(4096), epochs=3)

# Use brute-force search to set up retrieval using the trained representations.
index = tfrs.layers.factorized_top_k.BruteForce(model.user_model)
index.index_from_dataset(
    movies.batch(100).map(lambda title: (title, model.movie_model(title))))

# Get some recommendations.
_, titles = index(np.array(["42"]))
print(f"Top 3 recommendations for user 42: {titles[0, :3]}")
# Out:
# Epoch 1/3
# 25/25 [==============================] - 25s 947ms/step - factorized_top_k/top_1_categorical_accuracy: 7.0000e-05 - factorized_top_k/top_5_categorical_accuracy: 0.0015 - factorized_top_k/top_10_categorical_accuracy: 0.0047 - factorized_top_k/top_50_categorical_accuracy: 0.0456 - factorized_top_k/top_100_categorical_accuracy: 0.1035 - loss: 33083.8682 - regularization_loss: 0.0000e+00 - total_loss: 33083.8682
# Epoch 2/3
# 25/25 [==============================] - 24s 973ms/step - factorized_top_k/top_1_categorical_accuracy: 1.9000e-04 - factorized_top_k/top_5_categorical_accuracy: 0.0055 - factorized_top_k/top_10_categorical_accuracy: 0.0149 - factorized_top_k/top_50_categorical_accuracy: 0.1049 - factorized_top_k/top_100_categorical_accuracy: 0.2108 - loss: 31014.4095 - regularization_loss: 0.0000e+00 - total_loss: 31014.4095
# Epoch 3/3
# ...
